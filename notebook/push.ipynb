# %%
# -*- coding: utf-8 -*-
#!/usr/bin/env python3

import requests
import datetime
from urllib.parse import urlparse
from bs4 import BeautifulSoup
import re
import codecs
import time

# %%
def get_response(url):
    response = requests.get(url)
    while not response.ok:
        response = requests.get(url)
    return response
class MemberCount(object):
    class CountInfo(object):
        def __init__(self, count):
            self.count = count
            self.name_list = []
        def insert_name(self, name):
            self.name_list.append(name)
            self.name_list.sort()
        def delete_name(self, name):
            self.name_list.remove(name)
        def get_count(self):
            return self.count
        def get_name_list(self):
            return self.name_list
    
    def __init__(self):
        # referience to count_table that contain the name 
        self.name_table = {}
        # key is count,  value is name list
        self.count_table = {}
        self.max_count = 0
    def add_count_by_name(self, name):
        if name not in self.name_table.keys():
            if 1 not in self.count_table:
                self.count_table[1] = self.CountInfo(1)
            self.count_table[1].insert_name(name)
            self.name_table[name] = self.count_table[1]
        else:
            #delete from orignal CountInfo object
            # and get count+1
            cur_count_object = self.name_table[name]
            count = cur_count_object.get_count()
            cur_count_object.delete_name(name)
            
            count = count + 1
            # check this count is biggest or not
            if self.max_count < count:
                self.max_count = count
            # insert to  count_table(count+1)
            if count not in self.count_table:
                self.count_table[count] = self.CountInfo(count)
            self.count_table[count].insert_name(name)
            self.name_table[name] = self.count_table[count]
    def get_top_ten_list(self):
        ret_list = []
        number = 0
        cur_count = self.max_count
        while number < 10:
            name_list = self.count_table[cur_count].get_name_list()
            for name in name_list:
                if number < 10:
                    ret_list.append((number+1, name, cur_count))
                    number = number + 1
                else:
                    return ret_list
            cur_count = cur_count - 1
        return ret_list

# %% [markdown]
# # main function #

# %%
start_date = 101
end_date = 1231
like_count = MemberCount()
boo_count = MemberCount()
all_like = 0
all_boo = 0
t1 = time.time()
all_file = codecs.open("all_articles.txt", "r", "utf-8")

print('search date between ' + str(start_date) + ' to ' + str(end_date))
for line in all_file:
    line_list=[x for x in line.split(',')]
    url = line_list[len(line_list)-1]
    date = int(line_list[0])

    #check date
    if end_date - start_date >= end_date - date and  end_date - date >= 0:
        print("look indside web")
        print(date)
        print(url)
        response = get_response(url.strip())
        soup = BeautifulSoup(response.text, 'lxml')
        exec_time = time.time()
        for push_soup in soup.find_all('div', 'push'):
            if push_soup.find('span', 'push-tag'):
                push_category = push_soup.find('span', 'push-tag').string.strip()
                push_name = push_soup.find('span', 'push-userid').string.strip()
                if push_category == '推':
                    all_like = all_like + 1
                    like_count.add_count_by_name(push_name)
                if push_category == '噓':
                    all_boo = all_boo + 1
                    boo_count.add_count_by_name(push_name)
        exec_finish_time = time.time()
        if exec_finish_time - exec_time < 0.1:
            print('sleep for a while ....')
            time.sleep(0.1)
    check_time = time.time()
    print("exec time now: %f" % ((check_time-t1)/60))
push_file = codecs.open("push[%d-%d].txt"%(start_date, end_date), "w", "utf-8")
push_file.write('all like: %d\n' % all_like)
push_file.write('all boo: %d\n' % all_boo)
like_top_ten_list = like_count.get_top_ten_list()
boo_top_ten_list = boo_count.get_top_ten_list()
for item in like_top_ten_list:
    push_file.write('like #%d: %s %d\n' % (item[0], item[1], item[2]))
for item in boo_top_ten_list:
    push_file.write('boo #%d: %s %d\n' % (item[0], item[1], item[2]))
push_file.close()
t2 = time.time()
total_time = (t2-t1)/60
print("total time: %f" % total_time)
# Out:
# search date between 101 to 1231
# look indside web
# 1231
# https://www.ptt.cc/bbs/Beauty/M.1514735605.A.11A.html
#
# sleep for a while ....
# exec time now: 0.044396
# look indside web
# 1231
# https://www.ptt.cc/bbs/Beauty/M.1514732322.A.F1F.html
#
# sleep for a while ....
# exec time now: 0.065878
# look indside web
# 1231
# https://www.ptt.cc/bbs/Beauty/M.1514729703.A.F6F.html
#
# exec time now: 0.101504
# look indside web
# 1231
# https://www.ptt.cc/bbs/Beauty/M.1514725206.A.A7F.html
#
# sleep for a while ....
# exec time now: 0.123169
# look indside web
# 1231
# https://www.ptt.cc/bbs/Beauty/M.1514716751.A.BF0.html
#
# sleep for a while ....
# exec time now: 0.145367
# look indside web
# 1231
# https://www.ptt.cc/bbs/Beauty/M.1514711622.A.06F.html
#
# sleep for a while ....
# exec time now: 0.171642
# look indside web
# 1231
# https://www.ptt.cc/bbs/Beauty/M.1514708220.A.D26.html
#
# sleep for a while ....
# exec time now: 0.189247
# look indside web
# 1231
# https://www.ptt.cc/bbs/Beauty/M.1514702591.A.257.html
#
# sleep for a while ....
# exec time now: 0.209148
# look indside web
# 1231
# https://www.ptt.cc/bbs/Beauty/M.1514699566.A.E18.html
#
# sleep for a while ....
# exec time now: 0.231329
# look indside web
# 1231
# https://www.ptt.cc/bbs/Beauty/M.1514694609.A.4EB.html
#
# sleep for a while ....
# exec time now: 0.255940
# look indside web
# 1231
# https://www.ptt.cc/bbs/Beauty/M.1514694564.A.9A9.html
#
# sleep for a while ....
# exec time now: 0.276207
# look indside web
# 1231
# https://www.ptt.cc/bbs/Beauty/M.1514691606.A.C24.html
#
# sleep for a while ....
# exec time now: 0.294228
# look indside web
# 1231
# https://www.ptt.cc/bbs/Beauty/M.1514685806.A.1FE.html
#
# sleep for a while ....
# exec time now: 0.315395
# look indside web
# 1231
# https://www.ptt.cc/bbs/Beauty/M.1514664088.A.F6E.html
#
# sleep for a while ....
# exec time now: 0.335529
# look indside web
# 1231
# https://www.ptt.cc/bbs/Beauty/M.1514657483.A.9C9.html
#
# sleep for a while ....
# exec time now: 0.364965
# look indside web
# 1231
# https://www.ptt.cc/bbs/Beauty/M.1514655710.A.A0B.html
#
# sleep for a while ....
# exec time now: 0.390075
# look indside web
# 1231
# https://www.ptt.cc/bbs/Beauty/M.1514655212.A.6B9.html
#
# sleep for a while ....
# exec time now: 0.411474
# look indside web
# 1231
# https://www.ptt.cc/bbs/Beauty/M.1514654470.A.BBE.html
#
# sleep for a while ....
# exec time now: 0.437482
# look indside web
# 1231
# https://www.ptt.cc/bbs/Beauty/M.1514652528.A.900.html
#
# sleep for a while ....
# exec time now: 0.458865
# look indside web
# 1230
# https://www.ptt.cc/bbs/Beauty/M.1514648652.A.60E.html
#
# sleep for a while ....
# exec time now: 0.483276
# look indside web
# 1230
# https://www.ptt.cc/bbs/Beauty/M.1514647888.A.BD4.html
#
# sleep for a while ....
# exec time now: 0.503626
# look indside web
# 1230
# https://www.ptt.cc/bbs/Beauty/M.1514644159.A.001.html
#
# sleep for a while ....
# exec time now: 0.534410
# look indside web
# 1230
# https://www.ptt.cc/bbs/Beauty/M.1514643769.A.D1E.html
#
# sleep for a while ....
# exec time now: 0.555909
# look indside web
# 1230
# https://www.ptt.cc/bbs/Beauty/M.1514636016.A.BD3.html
#
# sleep for a while ....
# exec time now: 0.575977
# look indside web
# 1230
# https://www.ptt.cc/bbs/Beauty/M.1514623732.A.9D9.html
#
# sleep for a while ....
# exec time now: 0.597459
# look indside web
# 1230
# https://www.ptt.cc/bbs/Beauty/M.1514619072.A.1FF.html
#
# sleep for a while ....
# exec time now: 0.617011
# look indside web
# 1230
# https://www.ptt.cc/bbs/Beauty/M.1514618609.A.D4F.html
#
# sleep for a while ....
# exec time now: 0.635914
# look indside web
# 1230
# https://www.ptt.cc/bbs/Beauty/M.1514613914.A.E46.html
#
# sleep for a while ....
# exec time now: 0.660591
# look indside web
# 1230
# https://www.ptt.cc/bbs/Beauty/M.1514607136.A.387.html
#
# sleep for a while ....
# exec time now: 0.684803
# look indside web
# 1230
# https://www.ptt.cc/bbs/Beauty/M.1514603368.A.482.html
#
# sleep for a while ....
# exec time now: 0.708997
# look indside web
# 1230
# https://www.ptt.cc/bbs/Beauty/M.1514593123.A.F17.html
#
# sleep for a while ....
# exec time now: 0.730945
# look indside web
# 1230
# https://www.ptt.cc/bbs/Beauty/M.1514590716.A.854.html
#
# exec time now: 0.771148
# look indside web
# 1230
# https://www.ptt.cc/bbs/Beauty/M.1514570203.A.591.html
#
# sleep for a while ....
# exec time now: 0.794676
# look indside web
# 1229
# https://www.ptt.cc/bbs/Beauty/M.1514556747.A.FAD.html
#
# sleep for a while ....
# exec time now: 0.820751
# look indside web
# 1229
# https://www.ptt.cc/bbs/Beauty/M.1514545225.A.C4E.html
#
# sleep for a while ....
# exec time now: 0.839671
# look indside web
# 1229
# https://www.ptt.cc/bbs/Beauty/M.1514543398.A.2F0.html
#
# sleep for a while ....
# exec time now: 0.859939
# look indside web
# 1229
# https://www.ptt.cc/bbs/Beauty/M.1514535514.A.B8A.html
#
# sleep for a while ....
# exec time now: 0.882336
# look indside web
# 1229
# https://www.ptt.cc/bbs/Beauty/M.1514535024.A.E4B.html
#
# sleep for a while ....
# exec time now: 0.899508
# look indside web
# 1229
# https://www.ptt.cc/bbs/Beauty/M.1514534802.A.5D0.html
#
# sleep for a while ....
# exec time now: 0.921856
# look indside web
# 1229
# https://www.ptt.cc/bbs/Beauty/M.1514534771.A.E08.html
#
# sleep for a while ....
# exec time now: 0.954936
# look indside web
# 1229
# https://www.ptt.cc/bbs/Beauty/M.1514534507.A.8BA.html
#
# sleep for a while ....
# exec time now: 0.980728
# look indside web
# 1229
# https://www.ptt.cc/bbs/Beauty/M.1514531519.A.8FC.html
#
# sleep for a while ....
# exec time now: 1.007935
# look indside web
# 1229
# https://www.ptt.cc/bbs/Beauty/M.1514529380.A.7B0.html
#
# sleep for a while ....
# exec time now: 1.033544
# look indside web
# 1229
# https://www.ptt.cc/bbs/Beauty/M.1514522008.A.84E.html
#
# sleep for a while ....
# exec time now: 1.055342
# look indside web
# 1229
# https://www.ptt.cc/bbs/Beauty/M.1514520794.A.061.html
#
# sleep for a while ....
# exec time now: 1.081999
# look indside web
# 1229
# https://www.ptt.cc/bbs/Beauty/M.1514519619.A.943.html
#
# sleep for a while ....
# exec time now: 1.102999
# look indside web
# 1229
# https://www.ptt.cc/bbs/Beauty/M.1514515935.A.352.html
#
# sleep for a while ....
# exec time now: 1.132685
# look indside web
# 1229
# https://www.ptt.cc/bbs/Beauty/M.1514511698.A.B25.html
#
# sleep for a while ....
# exec time now: 1.156547
# look indside web
# 1229
# https://www.ptt.cc/bbs/Beauty/M.1514501084.A.AEF.html
#
# sleep for a while ....
# exec time now: 1.177779
# look indside web
# 1229
# https://www.ptt.cc/bbs/Beauty/M.1514493702.A.7DE.html
#
# sleep for a while ....
# exec time now: 1.208114
# look indside web
# 1229
# https://www.ptt.cc/bbs/Beauty/M.1514493253.A.35D.html
#
# sleep for a while ....
# exec time now: 1.225603
# look indside web
# 1229
# https://www.ptt.cc/bbs/Beauty/M.1514487256.A.A40.html
#
# sleep for a while ....
# exec time now: 1.246769
# look indside web
# 1228
# https://www.ptt.cc/bbs/Beauty/M.1514475436.A.6BF.html
#
# sleep for a while ....
# exec time now: 1.266420
# look indside web
# 1228
# https://www.ptt.cc/bbs/Beauty/M.1514473340.A.725.html
#
# sleep for a while ....
# exec time now: 1.289716
# look indside web
# 1228
# https://www.ptt.cc/bbs/Beauty/M.1514470995.A.F7D.html
#
# sleep for a while ....
# exec time now: 1.315508
# look indside web
# 1228
# https://www.ptt.cc/bbs/Beauty/M.1514466695.A.D00.html
#
# sleep for a while ....
# exec time now: 1.337140
# look indside web
# 1228
# https://www.ptt.cc/bbs/Beauty/M.1514462843.A.318.html
#
# sleep for a while ....
# exec time now: 1.358723
# look indside web
# 1228
# https://www.ptt.cc/bbs/Beauty/M.1514462600.A.0B0.html
#
# sleep for a while ....
# exec time now: 1.380022
# look indside web
# 1228
# https://www.ptt.cc/bbs/Beauty/M.1514458719.A.D52.html
#
# sleep for a while ....
# exec time now: 1.400772
# look indside web
# 1228
# https://www.ptt.cc/bbs/Beauty/M.1514456648.A.F75.html
#
# sleep for a while ....
# exec time now: 1.422653
# look indside web
# 1228
# https://www.ptt.cc/bbs/Beauty/M.1514454309.A.613.html
#
# sleep for a while ....
# exec time now: 1.440109
# look indside web
# 1228
# https://www.ptt.cc/bbs/Beauty/M.1514452249.A.BE5.html
#
# sleep for a while ....
# exec time now: 1.459894
# look indside web
# 1228
# https://www.ptt.cc/bbs/Beauty/M.1514446930.A.EF7.html
#
# sleep for a while ....
# exec time now: 1.481027
# look indside web
# 1228
# https://www.ptt.cc/bbs/Beauty/M.1514445473.A.82E.html
#
# sleep for a while ....
# exec time now: 1.508050
# look indside web
# 1228
# https://www.ptt.cc/bbs/Beauty/M.1514442542.A.B09.html
#
# sleep for a while ....
# exec time now: 1.534541
# look indside web
# 1228
# https://www.ptt.cc/bbs/Beauty/M.1514442448.A.4A3.html
#
# sleep for a while ....
# exec time now: 1.560915
# look indside web
# 1228
# https://www.ptt.cc/bbs/Beauty/M.1514439471.A.625.html
# sleep for a while ....
# exec time now: 1.582947
# look indside web
# 1228
# https://www.ptt.cc/bbs/Beauty/M.1514437354.A.EAD.html
#
# sleep for a while ....
# exec time now: 1.602865
# look indside web
# 1228
# https://www.ptt.cc/bbs/Beauty/M.1514434299.A.432.html
#
# sleep for a while ....
# exec time now: 1.620886
# look indside web
# 1228
# https://www.ptt.cc/bbs/Beauty/M.1514433235.A.86D.html
#
# sleep for a while ....
# exec time now: 1.638424
# look indside web
# 1228
# https://www.ptt.cc/bbs/Beauty/M.1514431619.A.F43.html
#
# sleep for a while ....
# exec time now: 1.656445
# look indside web
# 1228
# https://www.ptt.cc/bbs/Beauty/M.1514424071.A.879.html
#
# sleep for a while ....
# exec time now: 1.674450
# look indside web
# 1228
# https://www.ptt.cc/bbs/Beauty/M.1514402414.A.272.html
#
# sleep for a while ....
# exec time now: 1.692837
# look indside web
# 1228
# https://www.ptt.cc/bbs/Beauty/M.1514393804.A.557.html
#
# sleep for a while ....
# exec time now: 1.710875
# look indside web
# 1227
# https://www.ptt.cc/bbs/Beauty/M.1514387334.A.89E.html
#
# sleep for a while ....
# exec time now: 1.732224
# look indside web
# 1227
# https://www.ptt.cc/bbs/Beauty/M.1514386505.A.223.html
#
# sleep for a while ....
# exec time now: 1.750828
# look indside web
# 1227
# https://www.ptt.cc/bbs/Beauty/M.1514383531.A.10F.html
#
# sleep for a while ....
# exec time now: 1.769664
# look indside web
# 1227
# https://www.ptt.cc/bbs/Beauty/M.1514379692.A.9C7.html
#
# sleep for a while ....
# exec time now: 1.787153
# look indside web
# 1227
# https://www.ptt.cc/bbs/Beauty/M.1514377720.A.F52.html
#
# sleep for a while ....
# exec time now: 1.810898
# look indside web
# 1227
# https://www.ptt.cc/bbs/Beauty/M.1514364941.A.ED2.html
#
# sleep for a while ....
# exec time now: 1.832680
# look indside web
# 1227
# https://www.ptt.cc/bbs/Beauty/M.1514359661.A.E06.html
#
# sleep for a while ....
# exec time now: 1.864812
# look indside web
# 1227
# https://www.ptt.cc/bbs/Beauty/M.1514358010.A.5AB.html
#
# sleep for a while ....
# exec time now: 1.885196
# look indside web
# 1227
# https://www.ptt.cc/bbs/Beauty/M.1514357226.A.DEA.html
#
# sleep for a while ....
# exec time now: 1.903167
# look indside web
# 1227
# https://www.ptt.cc/bbs/Beauty/M.1514352512.A.E8F.html
#
# sleep for a while ....
# exec time now: 1.923151
# look indside web
# 1227
# https://www.ptt.cc/bbs/Beauty/M.1514352107.A.F6B.html
#
# sleep for a while ....
# exec time now: 1.941622
# look indside web
# 1227
# https://www.ptt.cc/bbs/Beauty/M.1514350958.A.CDE.html
#
# sleep for a while ....
# exec time now: 1.962771
# look indside web
# 1227
# https://www.ptt.cc/bbs/Beauty/M.1514341490.A.D2E.html
#
# sleep for a while ....
# exec time now: 1.981774
# look indside web
# 1227
# https://www.ptt.cc/bbs/Beauty/M.1514336868.A.874.html
#
# sleep for a while ....
# exec time now: 2.002208
# look indside web
# 1227
# https://www.ptt.cc/bbs/Beauty/M.1514333815.A.A9B.html
#
# sleep for a while ....
# exec time now: 2.024439
# look indside web
# 1227
# https://www.ptt.cc/bbs/Beauty/M.1514331569.A.2C9.html
#
# sleep for a while ....
# exec time now: 2.042493
# look indside web
# 1227
# https://www.ptt.cc/bbs/Beauty/M.1514312258.A.AF6.html
#
# sleep for a while ....
# exec time now: 2.062561
# look indside web
# 1227
# https://www.ptt.cc/bbs/Beauty/M.1514304217.A.3DC.html
#
# sleep for a while ....
# exec time now: 2.088253
# look indside web
# 1226
# https://www.ptt.cc/bbs/Beauty/M.1514299160.A.F89.html
#
# sleep for a while ....
# exec time now: 2.109320
# look indside web
# 1226
# https://www.ptt.cc/bbs/Beauty/M.1514298587.A.720.html
#
# sleep for a while ....
# exec time now: 2.133880
# look indside web
# 1226
# https://www.ptt.cc/bbs/Beauty/M.1514294793.A.7A9.html
#
# sleep for a while ....
# exec time now: 2.152467
# look indside web
# 1226
# https://www.ptt.cc/bbs/Beauty/M.1514291425.A.C36.html
#
# sleep for a while ....
# exec time now: 2.173833
# look indside web
# 1226
# https://www.ptt.cc/bbs/Beauty/M.1514290381.A.D39.html
#
# sleep for a while ....
# exec time now: 2.193119
# look indside web
# 1226
# https://www.ptt.cc/bbs/Beauty/M.1514288950.A.692.html
#
# sleep for a while ....
# exec time now: 2.212172
# look indside web
# 1226
# https://www.ptt.cc/bbs/Beauty/M.1514287693.A.3F6.html
#
# sleep for a while ....
# exec time now: 2.237364
# look indside web
# 1226
# https://www.ptt.cc/bbs/Beauty/M.1514285522.A.EA7.html
#
# sleep for a while ....
# exec time now: 2.258863
# look indside web
# 1226
# https://www.ptt.cc/bbs/Beauty/M.1514283365.A.4C8.html
#
# sleep for a while ....
# exec time now: 2.277916
# look indside web
# 1226
# https://www.ptt.cc/bbs/Beauty/M.1514265088.A.9B8.html
#
# sleep for a while ....
# exec time now: 2.302144
# look indside web
# 1226
# https://www.ptt.cc/bbs/Beauty/M.1514262360.A.C32.html
#
# sleep for a while ....
# exec time now: 2.326422
# look indside web
# 1226
# https://www.ptt.cc/bbs/Beauty/M.1514260789.A.55E.html
#
# sleep for a while ....
# exec time now: 2.345774
# look indside web
# 1226
# https://www.ptt.cc/bbs/Beauty/M.1514258028.A.C01.html
#
# sleep for a while ....
# exec time now: 2.368820
# look indside web
# 1226
# https://www.ptt.cc/bbs/Beauty/M.1514251369.A.E6B.html
#
# sleep for a while ....
# exec time now: 2.386858
# look indside web
# 1226
# https://www.ptt.cc/bbs/Beauty/M.1514250121.A.F51.html
#
# sleep for a while ....
# exec time now: 2.406726
# look indside web
# 1226
# https://www.ptt.cc/bbs/Beauty/M.1514248546.A.B0D.html
#
# sleep for a while ....
# exec time now: 2.424748
# look indside web
# 1226
# https://www.ptt.cc/bbs/Beauty/M.1514223820.A.8DB.html
#
# sleep for a while ....
# exec time now: 2.445647
# look indside web
# 1226
# https://www.ptt.cc/bbs/Beauty/M.1514221323.A.3C2.html
#
# sleep for a while ....
# exec time now: 2.464301
# look indside web
# 1226
# https://www.ptt.cc/bbs/Beauty/M.1514218144.A.83D.html
#
# sleep for a while ....
# exec time now: 2.486915
# look indside web
# 1226
# https://www.ptt.cc/bbs/Beauty/M.1514218051.A.E3F.html
#
# sleep for a while ....
# exec time now: 2.509179
# look indside web
# 1225
# https://www.ptt.cc/bbs/Beauty/M.1514212220.A.0BC.html
#
# sleep for a while ....
# exec time now: 2.535503
# look indside web
# 1225
# https://www.ptt.cc/bbs/Beauty/M.1514211010.A.6DF.html
#
# sleep for a while ....
# exec time now: 2.554556
# look indside web
# 1225
# https://www.ptt.cc/bbs/Beauty/M.1514209511.A.6BA.html
#
# sleep for a while ....
# exec time now: 2.573276
# look indside web
# 1225
# https://www.ptt.cc/bbs/Beauty/M.1514206412.A.043.html
#
# sleep for a while ....
# exec time now: 2.593976
# look indside web
# 1225
# https://www.ptt.cc/bbs/Beauty/M.1514205052.A.218.html
#
# sleep for a while ....
# exec time now: 2.616989
# look indside web
# 1225
# https://www.ptt.cc/bbs/Beauty/M.1514204776.A.EE1.html
#
# sleep for a while ....
# exec time now: 2.636658
# look indside web
# 1225
# https://www.ptt.cc/bbs/Beauty/M.1514204271.A.C74.html
#
# sleep for a while ....
# exec time now: 2.658207
# look indside web
# 1225
# https://www.ptt.cc/bbs/Beauty/M.1514203196.A.AB0.html
#
# sleep for a while ....
# exec time now: 2.679406
# look indside web
# 1225
# https://www.ptt.cc/bbs/Beauty/M.1514197139.A.CD4.html
#
# sleep for a while ....
# exec time now: 2.697327
# look indside web
# 1225
# https://www.ptt.cc/bbs/Beauty/M.1514195641.A.108.html
#
# sleep for a while ....
# exec time now: 2.714999
# look indside web
# 1225
# https://www.ptt.cc/bbs/Beauty/M.1514190561.A.B9F.html
#
# sleep for a while ....
# exec time now: 2.738378
# look indside web
# 1225
# https://www.ptt.cc/bbs/Beauty/M.1514190156.A.A60.html
#
# sleep for a while ....
# exec time now: 2.756017
# look indside web
# 1225
# https://www.ptt.cc/bbs/Beauty/M.1514189126.A.FD9.html
#
# sleep for a while ....
# exec time now: 2.773805
# look indside web
# 1225
# https://www.ptt.cc/bbs/Beauty/M.1514188439.A.CE4.html
#
# sleep for a while ....
# exec time now: 2.796269
# look indside web
# 1225
# https://www.ptt.cc/bbs/Beauty/M.1514187672.A.704.html
#
# sleep for a while ....
# exec time now: 2.818001
# look indside web
# 1225
# https://www.ptt.cc/bbs/Beauty/M.1514181810.A.05F.html
#
# sleep for a while ....
# exec time now: 2.838418
# look indside web
# 1225
# https://www.ptt.cc/bbs/Beauty/M.1514177496.A.0CA.html
#
# sleep for a while ....
# exec time now: 2.858669
# look indside web
# 1225
# https://www.ptt.cc/bbs/Beauty/M.1514174535.A.4FC.html
#
# sleep for a while ....
# exec time now: 2.879269
# look indside web
# 1225
# https://www.ptt.cc/bbs/Beauty/M.1514172333.A.06F.html
#
# sleep for a while ....
# exec time now: 2.897507
# look indside web
# 1225
# https://www.ptt.cc/bbs/Beauty/M.1514169454.A.886.html
#
# sleep for a while ....
# exec time now: 2.915411
# look indside web
# 1225
# https://www.ptt.cc/bbs/Beauty/M.1514168943.A.5B2.html
#
# sleep for a while ....
# exec time now: 2.933715
# look indside web
# 1225
# https://www.ptt.cc/bbs/Beauty/M.1514168091.A.4F9.html
# sleep for a while ....
# exec time now: 2.951770
# look indside web
# 1225
# https://www.ptt.cc/bbs/Beauty/M.1514166668.A.22A.html
#
# sleep for a while ....
# exec time now: 2.969807
# look indside web
# 1225
# https://www.ptt.cc/bbs/Beauty/M.1514163027.A.991.html
#
# sleep for a while ....
# exec time now: 2.988744
# look indside web
# 1225
# https://www.ptt.cc/bbs/Beauty/M.1514162634.A.381.html
#
# sleep for a while ....
# exec time now: 3.005999
# look indside web
# 1225
# https://www.ptt.cc/bbs/Beauty/M.1514162012.A.871.html
#
# sleep for a while ....
# exec time now: 3.023538
# look indside web
# 1225
# https://www.ptt.cc/bbs/Beauty/M.1514145377.A.CC2.html
#
# sleep for a while ....
# exec time now: 3.041409
# look indside web
# 1225
# https://www.ptt.cc/bbs/Beauty/M.1514138195.A.67D.html
#
# sleep for a while ....
# exec time now: 3.062476
# look indside web
# 1225
# https://www.ptt.cc/bbs/Beauty/M.1514132368.A.C58.html
#
# sleep for a while ....
# exec time now: 3.080397
# look indside web
# 1224
# https://www.ptt.cc/bbs/Beauty/M.1514130022.A.D28.html
#
# sleep for a while ....
# exec time now: 3.097885
# look indside web
# 1224
# https://www.ptt.cc/bbs/Beauty/M.1514130004.A.477.html
#
# sleep for a while ....
# exec time now: 3.116622
# look indside web
# 1224
# https://www.ptt.cc/bbs/Beauty/M.1514129265.A.C08.html
#
# sleep for a while ....
# exec time now: 3.135226
# look indside web
# 1224
# https://www.ptt.cc/bbs/Beauty/M.1514126598.A.CA4.html
#
# sleep for a while ....
# exec time now: 3.152548
# look indside web
# 1224
# https://www.ptt.cc/bbs/Beauty/M.1514125332.A.D86.html
#
# sleep for a while ....
# exec time now: 3.170469
# look indside web
# 1224
# https://www.ptt.cc/bbs/Beauty/M.1514124308.A.4EB.html
#
# sleep for a while ....
# exec time now: 3.189638
# look indside web
# 1224
# https://www.ptt.cc/bbs/Beauty/M.1514123815.A.63D.html
#
# sleep for a while ....
# exec time now: 3.206428
# look indside web
# 1224
# https://www.ptt.cc/bbs/Beauty/M.1514117606.A.A80.html
#
# sleep for a while ....
# exec time now: 3.228526
# look indside web
# 1224
# https://www.ptt.cc/bbs/Beauty/M.1514112784.A.264.html
#
# sleep for a while ....
# exec time now: 3.250857
# look indside web
# 1224
# https://www.ptt.cc/bbs/Beauty/M.1514111360.A.B8E.html
#
# sleep for a while ....
# exec time now: 3.268945
# look indside web
# 1224
# https://www.ptt.cc/bbs/Beauty/M.1514110483.A.AF5.html
#
# sleep for a while ....
# exec time now: 3.286134
# look indside web
# 1224
# https://www.ptt.cc/bbs/Beauty/M.1514106526.A.2B9.html
#
# sleep for a while ....
# exec time now: 3.302973
# look indside web
# 1224
# https://www.ptt.cc/bbs/Beauty/M.1514101585.A.790.html
#
# sleep for a while ....
# exec time now: 3.320029
# look indside web
# 1224
# https://www.ptt.cc/bbs/Beauty/M.1514099710.A.90C.html
#
# sleep for a while ....
# exec time now: 3.337801
# look indside web
# 1224
# https://www.ptt.cc/bbs/Beauty/M.1514096377.A.E60.html
#
# sleep for a while ....
# exec time now: 3.354624
# look indside web
# 1224
# https://www.ptt.cc/bbs/Beauty/M.1514091449.A.208.html
#
# sleep for a while ....
# exec time now: 3.371597
# look indside web
# 1224
# https://www.ptt.cc/bbs/Beauty/M.1514091311.A.49A.html
#
# sleep for a while ....
# exec time now: 3.388420
# look indside web
# 1224
# https://www.ptt.cc/bbs/Beauty/M.1514082914.A.2F0.html
#
# sleep for a while ....
# exec time now: 3.405692
# look indside web
# 1224
# https://www.ptt.cc/bbs/Beauty/M.1514073597.A.7E5.html
#
# sleep for a while ....
# exec time now: 3.423000
# look indside web
# 1224
# https://www.ptt.cc/bbs/Beauty/M.1514055961.A.BD6.html
#
# sleep for a while ....
# exec time now: 3.440641
# look indside web
# 1224
# https://www.ptt.cc/bbs/Beauty/M.1514049050.A.0C8.html
#
# sleep for a while ....
# exec time now: 3.458099
# look indside web
# 1223
# https://www.ptt.cc/bbs/Beauty/M.1514044051.A.430.html
#
# sleep for a while ....
# exec time now: 3.474791
# look indside web
# 1223
# https://www.ptt.cc/bbs/Beauty/M.1514041584.A.33F.html
#
# sleep for a while ....
# exec time now: 3.491233
# look indside web
# 1223
# https://www.ptt.cc/bbs/Beauty/M.1514041474.A.80E.html
#
# sleep for a while ....
# exec time now: 3.508391
# look indside web
# 1223
# https://www.ptt.cc/bbs/Beauty/M.1514040107.A.7A5.html
#
# sleep for a while ....
# exec time now: 3.525882
# look indside web
# 1223
# https://www.ptt.cc/bbs/Beauty/M.1514039190.A.3A7.html
#
# sleep for a while ....
# exec time now: 3.544056
# look indside web
# 1223
# https://www.ptt.cc/bbs/Beauty/M.1514039019.A.63B.html
#
# sleep for a while ....
# exec time now: 3.560998
# look indside web
# 1223
# https://www.ptt.cc/bbs/Beauty/M.1514030809.A.C5F.html
#
# sleep for a while ....
# exec time now: 3.578173
# look indside web
# 1223
# https://www.ptt.cc/bbs/Beauty/M.1514030248.A.E32.html
#
# sleep for a while ....
# exec time now: 3.595314
# look indside web
# 1223
# https://www.ptt.cc/bbs/Beauty/M.1514028637.A.82F.html
#
# sleep for a while ....
# exec time now: 3.616287
# look indside web
# 1223
# https://www.ptt.cc/bbs/Beauty/M.1514026641.A.6D7.html
#
# sleep for a while ....
# exec time now: 3.634444
# look indside web
# 1223
# https://www.ptt.cc/bbs/Beauty/M.1514021720.A.542.html
#
# sleep for a while ....
# exec time now: 3.651919
# look indside web
# 1223
# https://www.ptt.cc/bbs/Beauty/M.1514018905.A.412.html
#
# sleep for a while ....
# exec time now: 3.668744
# look indside web
# 1223
# https://www.ptt.cc/bbs/Beauty/M.1514016896.A.D33.html
#
# sleep for a while ....
# exec time now: 3.691782
# look indside web
# 1223
# https://www.ptt.cc/bbs/Beauty/M.1514013411.A.ABE.html
#
# sleep for a while ....
# exec time now: 3.708491
# look indside web
# 1223
# https://www.ptt.cc/bbs/Beauty/M.1514010290.A.3A1.html
#
# sleep for a while ....
# exec time now: 3.725882
# look indside web
# 1223
# https://www.ptt.cc/bbs/Beauty/M.1514009984.A.F9D.html
#
# sleep for a while ....
# exec time now: 3.742940
# look indside web
# 1223
# https://www.ptt.cc/bbs/Beauty/M.1514009329.A.479.html
#
# sleep for a while ....
# exec time now: 3.759682
# look indside web
# 1223
# https://www.ptt.cc/bbs/Beauty/M.1514007276.A.044.html
#
# sleep for a while ....
# exec time now: 3.776507
# look indside web
# 1223
# https://www.ptt.cc/bbs/Beauty/M.1513999288.A.A3F.html
#
# sleep for a while ....
# exec time now: 3.793232
# look indside web
# 1223
# https://www.ptt.cc/bbs/Beauty/M.1513997912.A.2FC.html
#
# sleep for a while ....
# exec time now: 3.811656
# look indside web
# 1223
# https://www.ptt.cc/bbs/Beauty/M.1513995409.A.FD6.html
#
# sleep for a while ....
# exec time now: 3.829497
# look indside web
# 1223
# https://www.ptt.cc/bbs/Beauty/M.1513994671.A.051.html
#
# sleep for a while ....
# exec time now: 3.847471
# look indside web
# 1223
# https://www.ptt.cc/bbs/Beauty/M.1513985543.A.7BF.html
#
# sleep for a while ....
# exec time now: 3.867111
# look indside web
# 1223
# https://www.ptt.cc/bbs/Beauty/M.1513970751.A.7D4.html
#
# sleep for a while ....
# exec time now: 3.885935
# look indside web
# 1223
# https://www.ptt.cc/bbs/Beauty/M.1513960043.A.769.html
#
# sleep for a while ....
# exec time now: 3.903960
# look indside web
# 1222
# https://www.ptt.cc/bbs/Beauty/M.1513956707.A.AC4.html
#
# sleep for a while ....
# exec time now: 3.920785
# look indside web
# 1222
# https://www.ptt.cc/bbs/Beauty/M.1513946986.A.E94.html
#
# sleep for a while ....
# exec time now: 3.937293
# look indside web
# 1222
# https://www.ptt.cc/bbs/Beauty/M.1513940548.A.B0C.html
#
# sleep for a while ....
# exec time now: 3.953785
# look indside web
# 1222
# https://www.ptt.cc/bbs/Beauty/M.1513938213.A.310.html
#
# sleep for a while ....
# exec time now: 3.971309
# look indside web
# 1222
# https://www.ptt.cc/bbs/Beauty/M.1513937905.A.37F.html
#
# sleep for a while ....
# exec time now: 3.987918
# look indside web
# 1222
# https://www.ptt.cc/bbs/Beauty/M.1513937111.A.20A.html
#
# sleep for a while ....
# exec time now: 4.004709
# look indside web
# 1222
# https://www.ptt.cc/bbs/Beauty/M.1513936338.A.6C7.html
#
# sleep for a while ....
# exec time now: 4.025832
# look indside web
# 1222
# https://www.ptt.cc/bbs/Beauty/M.1513934099.A.356.html
#
# sleep for a while ....
# exec time now: 4.043623
# look indside web
# 1222
# https://www.ptt.cc/bbs/Beauty/M.1513933960.A.355.html
#
# sleep for a while ....
# exec time now: 4.060148
# look indside web
# 1222
# https://www.ptt.cc/bbs/Beauty/M.1513931398.A.7D3.html
#
# sleep for a while ....
# exec time now: 4.080188
# look indside web
# 1222
# https://www.ptt.cc/bbs/Beauty/M.1513929537.A.8EF.html
#
# sleep for a while ....
# exec time now: 4.097480
# look indside web
# 1222
# https://www.ptt.cc/bbs/Beauty/M.1513927608.A.4FF.html
#
# sleep for a while ....
# exec time now: 4.114771
# look indside web
# 1222
# https://www.ptt.cc/bbs/Beauty/M.1513925051.A.078.html
#
# exec time now: 4.133695
# look indside web
# 1222
# https://www.ptt.cc/bbs/Beauty/M.1513923537.A.10B.html
# sleep for a while ....
# exec time now: 4.150353
# look indside web
# 1222
# https://www.ptt.cc/bbs/Beauty/M.1513898280.A.666.html
#
# sleep for a while ....
# exec time now: 4.168227
# look indside web
# 1222
# https://www.ptt.cc/bbs/Beauty/M.1513887900.A.8CC.html
#
# sleep for a while ....
# exec time now: 4.186218
# look indside web
# 1222
# https://www.ptt.cc/bbs/Beauty/M.1513877662.A.D28.html
#
# sleep for a while ....
# exec time now: 4.204659
# look indside web
# 1221
# https://www.ptt.cc/bbs/Beauty/M.1513853104.A.886.html
#
# sleep for a while ....
# exec time now: 4.224333
# look indside web
# 1221
# https://www.ptt.cc/bbs/Beauty/M.1513850917.A.599.html
#
# sleep for a while ....
# exec time now: 4.243706
# look indside web
# 1221
# https://www.ptt.cc/bbs/Beauty/M.1513845039.A.CEA.html
#
# sleep for a while ....
# exec time now: 4.261797
# look indside web
# 1221
# https://www.ptt.cc/bbs/Beauty/M.1513842515.A.B80.html
#
# sleep for a while ....
# exec time now: 4.280055
# look indside web
# 1221
# https://www.ptt.cc/bbs/Beauty/M.1513831634.A.213.html
#
# sleep for a while ....
# exec time now: 4.297146
# look indside web
# 1221
# https://www.ptt.cc/bbs/Beauty/M.1513831354.A.656.html
#
# sleep for a while ....
# exec time now: 4.314538
# look indside web
# 1221
# https://www.ptt.cc/bbs/Beauty/M.1513828845.A.52C.html
#
# sleep for a while ....
# exec time now: 4.332579
# look indside web
# 1221
# https://www.ptt.cc/bbs/Beauty/M.1513827326.A.14B.html
#
# sleep for a while ....
# exec time now: 4.350037
# look indside web
# 1221
# https://www.ptt.cc/bbs/Beauty/M.1513825394.A.E9B.html
#
# sleep for a while ....
# exec time now: 4.367245
# look indside web
# 1221
# https://www.ptt.cc/bbs/Beauty/M.1513825188.A.AE0.html
#
# sleep for a while ....
# exec time now: 4.386102
# look indside web
# 1221
# https://www.ptt.cc/bbs/Beauty/M.1513824323.A.CA1.html
#
# sleep for a while ....
# exec time now: 4.403810
# look indside web
# 1221
# https://www.ptt.cc/bbs/Beauty/M.1513824060.A.E6D.html
#
# sleep for a while ....
# exec time now: 4.420585
# look indside web
# 1221
# https://www.ptt.cc/bbs/Beauty/M.1513822208.A.132.html
#
# sleep for a while ....
# exec time now: 4.438342
# look indside web
# 1221
# https://www.ptt.cc/bbs/Beauty/M.1513821816.A.51B.html
#
# sleep for a while ....
# exec time now: 4.455467
# look indside web
# 1221
# https://www.ptt.cc/bbs/Beauty/M.1513821674.A.17A.html
#
# sleep for a while ....
# exec time now: 4.472875
# look indside web
# 1221
# https://www.ptt.cc/bbs/Beauty/M.1513817217.A.F69.html
#
# sleep for a while ....
# exec time now: 4.489883
# look indside web
# 1221
# https://www.ptt.cc/bbs/Beauty/M.1513788348.A.769.html
#
# sleep for a while ....
# exec time now: 4.508374
# look indside web
# 1220
# https://www.ptt.cc/bbs/Beauty/M.1513783283.A.604.html
#
# sleep for a while ....
# exec time now: 4.527798
# look indside web
# 1220
# https://www.ptt.cc/bbs/Beauty/M.1513781813.A.4AD.html
#
# sleep for a while ....
# exec time now: 4.545305
# look indside web
# 1220
# https://www.ptt.cc/bbs/Beauty/M.1513781216.A.1B8.html
#
# sleep for a while ....
# exec time now: 4.562314
# look indside web
# 1220
# https://www.ptt.cc/bbs/Beauty/M.1513775439.A.ADD.html
#
# sleep for a while ....
# exec time now: 4.581554
# look indside web
# 1220
# https://www.ptt.cc/bbs/Beauty/M.1513773684.A.560.html
#
# exec time now: 4.606092
# look indside web
# 1220
# https://www.ptt.cc/bbs/Beauty/M.1513768720.A.241.html
#
# sleep for a while ....
# exec time now: 4.626781
# look indside web
# 1220
# https://www.ptt.cc/bbs/Beauty/M.1513768457.A.9DC.html
#
# sleep for a while ....
# exec time now: 4.645072
# look indside web
# 1220
# https://www.ptt.cc/bbs/Beauty/M.1513763466.A.FD6.html
#
# sleep for a while ....
# exec time now: 4.662997
# look indside web
# 1220
# https://www.ptt.cc/bbs/Beauty/M.1513761474.A.4F2.html
#
# sleep for a while ....
# exec time now: 4.680588
# look indside web
# 1220
# https://www.ptt.cc/bbs/Beauty/M.1513760779.A.6C4.html
#
# sleep for a while ....
# exec time now: 4.703060
# look indside web
# 1220
# https://www.ptt.cc/bbs/Beauty/M.1513760417.A.03B.html
#
# sleep for a while ....
# exec time now: 4.721101
# look indside web
# 1220
# https://www.ptt.cc/bbs/Beauty/M.1513759813.A.9DB.html
#
# sleep for a while ....
# exec time now: 4.743456
# look indside web
# 1220
# https://www.ptt.cc/bbs/Beauty/M.1513758848.A.3FC.html
#
# sleep for a while ....
# exec time now: 4.768194
# look indside web
# 1220
# https://www.ptt.cc/bbs/Beauty/M.1513752795.A.659.html
#
# sleep for a while ....
# exec time now: 4.795131
# look indside web
# 1220
# https://www.ptt.cc/bbs/Beauty/M.1513751778.A.175.html
#
# sleep for a while ....
# exec time now: 4.816603
# look indside web
# 1220
# https://www.ptt.cc/bbs/Beauty/M.1513745972.A.75D.html
#
# sleep for a while ....
# exec time now: 4.837243
# look indside web
# 1220
# https://www.ptt.cc/bbs/Beauty/M.1513743287.A.4E2.html
#
# sleep for a while ....
# exec time now: 4.854401
# look indside web
# 1220
# https://www.ptt.cc/bbs/Beauty/M.1513740330.A.AA0.html
#
# sleep for a while ....
# exec time now: 4.871509
# look indside web
# 1220
# https://www.ptt.cc/bbs/Beauty/M.1513740242.A.7AE.html
#
# sleep for a while ....
# exec time now: 4.889633
# look indside web
# 1220
# https://www.ptt.cc/bbs/Beauty/M.1513738736.A.603.html
#
# sleep for a while ....
# exec time now: 4.907308
# look indside web
# 1220
# https://www.ptt.cc/bbs/Beauty/M.1513738319.A.65A.html
#
# sleep for a while ....
# exec time now: 4.924299
# look indside web
# 1220
# https://www.ptt.cc/bbs/Beauty/M.1513729627.A.9EB.html
#
# sleep for a while ....
# exec time now: 4.944373
# look indside web
# 1220
# https://www.ptt.cc/bbs/Beauty/M.1513706367.A.598.html
#
# sleep for a while ....
# exec time now: 4.961664
# look indside web
# 1220
# https://www.ptt.cc/bbs/Beauty/M.1513701850.A.7EB.html
#
# sleep for a while ....
# exec time now: 4.978622
# look indside web
# 1219
# https://www.ptt.cc/bbs/Beauty/M.1513697516.A.6A7.html
#
# sleep for a while ....
# exec time now: 4.995830
# look indside web
# 1219
# https://www.ptt.cc/bbs/Beauty/M.1513695887.A.F0F.html
#
# sleep for a while ....
# exec time now: 5.014171
# look indside web
# 1219
# https://www.ptt.cc/bbs/Beauty/M.1513694213.A.303.html
#
# sleep for a while ....
# exec time now: 5.032812
# look indside web
# 1219
# https://www.ptt.cc/bbs/Beauty/M.1513692419.A.B19.html
#
# sleep for a while ....
# exec time now: 5.051502
# look indside web
# 1219
# https://www.ptt.cc/bbs/Beauty/M.1513691840.A.2D3.html
#
# sleep for a while ....
# exec time now: 5.069610
# look indside web
# 1219
# https://www.ptt.cc/bbs/Beauty/M.1513687618.A.E54.html
#
# sleep for a while ....
# exec time now: 5.089233
# look indside web
# 1219
# https://www.ptt.cc/bbs/Beauty/M.1513684166.A.B94.html
#
# sleep for a while ....
# exec time now: 5.106725
# look indside web
# 1219
# https://www.ptt.cc/bbs/Beauty/M.1513682307.A.AEE.html
#
# sleep for a while ....
# exec time now: 5.123416
# look indside web
# 1219
# https://www.ptt.cc/bbs/Beauty/M.1513671930.A.B18.html
#
# sleep for a while ....
# exec time now: 5.140641
# look indside web
# 1219
# https://www.ptt.cc/bbs/Beauty/M.1513671094.A.4EE.html
#
# sleep for a while ....
# exec time now: 5.162613
# look indside web
# 1219
# https://www.ptt.cc/bbs/Beauty/M.1513670496.A.44D.html
#
# sleep for a while ....
# exec time now: 5.183503
# look indside web
# 1219
# https://www.ptt.cc/bbs/Beauty/M.1513667719.A.0ED.html
#
# sleep for a while ....
# exec time now: 5.200911
# look indside web
# 1219
# https://www.ptt.cc/bbs/Beauty/M.1513666631.A.C94.html
#
# sleep for a while ....
# exec time now: 5.220918
# look indside web
# 1219
# https://www.ptt.cc/bbs/Beauty/M.1513666603.A.58B.html
#
# sleep for a while ....
# exec time now: 5.242956
# look indside web
# 1219
# https://www.ptt.cc/bbs/Beauty/M.1513666115.A.03F.html
#
# sleep for a while ....
# exec time now: 5.261830
# look indside web
# 1219
# https://www.ptt.cc/bbs/Beauty/M.1513654699.A.9C1.html
#
# sleep for a while ....
# exec time now: 5.282970
# look indside web
# 1219
# https://www.ptt.cc/bbs/Beauty/M.1513651042.A.594.html
#
# sleep for a while ....
# exec time now: 5.301427
# look indside web
# 1219
# https://www.ptt.cc/bbs/Beauty/M.1513649815.A.BCD.html
#
# sleep for a while ....
# exec time now: 5.322483
# look indside web
# 1219
# https://www.ptt.cc/bbs/Beauty/M.1513649144.A.61B.html
#
# sleep for a while ....
# exec time now: 5.339408
# look indside web
# 1218
# https://www.ptt.cc/bbs/Beauty/M.1513609664.A.E9C.html
#
# sleep for a while ....
# exec time now: 5.358532
# look indside web
# 1218
# https://www.ptt.cc/bbs/Beauty/M.1513597452.A.BB4.html
#
# sleep for a while ....
# exec time now: 5.377489
# look indside web
# 1218
# https://www.ptt.cc/bbs/Beauty/M.1513594180.A.792.html
#
# sleep for a while ....
# exec time now: 5.397113
# look indside web
# 1218
# https://www.ptt.cc/bbs/Beauty/M.1513592155.A.A75.html
# sleep for a while ....
# exec time now: 5.414071
# look indside web
# 1218
# https://www.ptt.cc/bbs/Beauty/M.1513589552.A.D75.html
#
# sleep for a while ....
# exec time now: 5.432762
# look indside web
# 1218
# https://www.ptt.cc/bbs/Beauty/M.1513588960.A.1D7.html
#
# sleep for a while ....
# exec time now: 5.450336
# look indside web
# 1218
# https://www.ptt.cc/bbs/Beauty/M.1513576783.A.AA3.html
#
# sleep for a while ....
# exec time now: 5.468610
# look indside web
# 1218
# https://www.ptt.cc/bbs/Beauty/M.1513574750.A.3CE.html
#
# sleep for a while ....
# exec time now: 5.487318
# look indside web
# 1218
# https://www.ptt.cc/bbs/Beauty/M.1513573618.A.7F3.html
#
# sleep for a while ....
# exec time now: 5.514271
# look indside web
# 1218
# https://www.ptt.cc/bbs/Beauty/M.1513572345.A.584.html
#
# sleep for a while ....
# exec time now: 5.541524
# look indside web
# 1218
# https://www.ptt.cc/bbs/Beauty/M.1513570729.A.ECA.html
#
# sleep for a while ....
# exec time now: 5.563729
# look indside web
# 1218
# https://www.ptt.cc/bbs/Beauty/M.1513570388.A.940.html
#
# sleep for a while ....
# exec time now: 5.584769
# look indside web
# 1218
# https://www.ptt.cc/bbs/Beauty/M.1513568256.A.B67.html
#
# sleep for a while ....
# exec time now: 5.605492
# look indside web
# 1218
# https://www.ptt.cc/bbs/Beauty/M.1513567917.A.E45.html
#
# sleep for a while ....
# exec time now: 5.630179
# look indside web
# 1218
# https://www.ptt.cc/bbs/Beauty/M.1513565628.A.5EA.html
#
# sleep for a while ....
# exec time now: 5.648404
# look indside web
# 1217
# https://www.ptt.cc/bbs/Beauty/M.1513518878.A.83C.html
#
# sleep for a while ....
# exec time now: 5.668843
# look indside web
# 1217
# https://www.ptt.cc/bbs/Beauty/M.1513517862.A.9B0.html
#
# sleep for a while ....
# exec time now: 5.686901
# look indside web
# 1217
# https://www.ptt.cc/bbs/Beauty/M.1513516204.A.DCB.html
#
# sleep for a while ....
# exec time now: 5.706358
# look indside web
# 1217
# https://www.ptt.cc/bbs/Beauty/M.1513514357.A.8B3.html
#
# sleep for a while ....
# exec time now: 5.723516
# look indside web
# 1217
# https://www.ptt.cc/bbs/Beauty/M.1513512752.A.C8E.html
#
# sleep for a while ....
# exec time now: 5.743073
# look indside web
# 1217
# https://www.ptt.cc/bbs/Beauty/M.1513504822.A.9F2.html
#
# sleep for a while ....
# exec time now: 5.760131
# look indside web
# 1217
# https://www.ptt.cc/bbs/Beauty/M.1513503888.A.E94.html
#
# sleep for a while ....
# exec time now: 5.781171
# look indside web
# 1217
# https://www.ptt.cc/bbs/Beauty/M.1513493758.A.F3E.html
#
# sleep for a while ....
# exec time now: 5.798162
# look indside web
# 1217
# https://www.ptt.cc/bbs/Beauty/M.1513476463.A.2E7.html
#
# sleep for a while ....
# exec time now: 5.815287
# look indside web
# 1217
# https://www.ptt.cc/bbs/Beauty/M.1513475117.A.107.html
#
# sleep for a while ....
# exec time now: 5.832778
# look indside web
# 1217
# https://www.ptt.cc/bbs/Beauty/M.1513454265.A.E25.html
#
# sleep for a while ....
# exec time now: 5.850586
# look indside web
# 1217
# https://www.ptt.cc/bbs/Beauty/M.1513444919.A.77C.html
#
# sleep for a while ....
# exec time now: 5.868660
# look indside web
# 1217
# https://www.ptt.cc/bbs/Beauty/M.1513442887.A.B87.html
#
# sleep for a while ....
# exec time now: 5.885252
# look indside web
# 1217
# https://www.ptt.cc/bbs/Beauty/M.1513440879.A.A1F.html
#
# sleep for a while ....
# exec time now: 5.902193
# look indside web
# 1216
# https://www.ptt.cc/bbs/Beauty/M.1513431241.A.70F.html
#
# sleep for a while ....
# exec time now: 5.919335
# look indside web
# 1216
# https://www.ptt.cc/bbs/Beauty/M.1513428940.A.792.html
#
# sleep for a while ....
# exec time now: 5.937126
# look indside web
# 1216
# https://www.ptt.cc/bbs/Beauty/M.1513427155.A.A07.html
#
# sleep for a while ....
# exec time now: 5.954484
# look indside web
# 1216
# https://www.ptt.cc/bbs/Beauty/M.1513427100.A.601.html
#
# sleep for a while ....
# exec time now: 5.971859
# look indside web
# 1216
# https://www.ptt.cc/bbs/Beauty/M.1513419202.A.DF3.html
#
# sleep for a while ....
# exec time now: 5.989117
# look indside web
# 1216
# https://www.ptt.cc/bbs/Beauty/M.1513418879.A.698.html
#
# sleep for a while ....
# exec time now: 6.005975
# look indside web
# 1216
# https://www.ptt.cc/bbs/Beauty/M.1513418109.A.8FA.html
#
# sleep for a while ....
# exec time now: 6.022500
# look indside web
# 1216
# https://www.ptt.cc/bbs/Beauty/M.1513416404.A.211.html
#
# sleep for a while ....
# exec time now: 6.039691
# look indside web
# 1216
# https://www.ptt.cc/bbs/Beauty/M.1513407366.A.424.html
#
# sleep for a while ....
# exec time now: 6.059182
# look indside web
# 1216
# https://www.ptt.cc/bbs/Beauty/M.1513405449.A.3D3.html
#
# sleep for a while ....
# exec time now: 6.075973
# look indside web
# 1216
# https://www.ptt.cc/bbs/Beauty/M.1513404333.A.C2B.html
#
# sleep for a while ....
# exec time now: 6.093648
# look indside web
# 1216
# https://www.ptt.cc/bbs/Beauty/M.1513396036.A.64B.html
#
# sleep for a while ....
# exec time now: 6.112238
# look indside web
# 1216
# https://www.ptt.cc/bbs/Beauty/M.1513395299.A.B31.html
#
# sleep for a while ....
# exec time now: 6.129513
# look indside web
# 1216
# https://www.ptt.cc/bbs/Beauty/M.1513394636.A.9BF.html
#
# sleep for a while ....
# exec time now: 6.156899
# look indside web
# 1216
# https://www.ptt.cc/bbs/Beauty/M.1513394308.A.00D.html
#
# sleep for a while ....
# exec time now: 6.174041
# look indside web
# 1216
# https://www.ptt.cc/bbs/Beauty/M.1513363919.A.4DB.html
#
# sleep for a while ....
# exec time now: 6.196380
# look indside web
# 1216
# https://www.ptt.cc/bbs/Beauty/M.1513357109.A.3B5.html
#
# sleep for a while ....
# exec time now: 6.213154
# look indside web
# 1216
# https://www.ptt.cc/bbs/Beauty/M.1513356995.A.C3B.html
#
# sleep for a while ....
# exec time now: 6.232412
# look indside web
# 1215
# https://www.ptt.cc/bbs/Beauty/M.1513350673.A.3CD.html
#
# sleep for a while ....
# exec time now: 6.249703
# look indside web
# 1215
# https://www.ptt.cc/bbs/Beauty/M.1513345647.A.AEF.html
#
# sleep for a while ....
# exec time now: 6.268443
# look indside web
# 1215
# https://www.ptt.cc/bbs/Beauty/M.1513344385.A.EDC.html
#
# sleep for a while ....
# exec time now: 6.286884
# look indside web
# 1215
# https://www.ptt.cc/bbs/Beauty/M.1513342023.A.935.html
#
# sleep for a while ....
# exec time now: 6.304142
# look indside web
# 1215
# https://www.ptt.cc/bbs/Beauty/M.1513327872.A.521.html
#
# sleep for a while ....
# exec time now: 6.322333
# look indside web
# 1215
# https://www.ptt.cc/bbs/Beauty/M.1513327218.A.B70.html
#
# sleep for a while ....
# exec time now: 6.339291
# look indside web
# 1215
# https://www.ptt.cc/bbs/Beauty/M.1513321140.A.0BE.html
#
# sleep for a while ....
# exec time now: 6.356216
# look indside web
# 1215
# https://www.ptt.cc/bbs/Beauty/M.1513317377.A.713.html
#
# sleep for a while ....
# exec time now: 6.373408
# look indside web
# 1215
# https://www.ptt.cc/bbs/Beauty/M.1513312315.A.26C.html
#
# sleep for a while ....
# exec time now: 6.391032
# look indside web
# 1215
# https://www.ptt.cc/bbs/Beauty/M.1513310408.A.77C.html
#
# sleep for a while ....
# exec time now: 6.407974
# look indside web
# 1215
# https://www.ptt.cc/bbs/Beauty/M.1513307844.A.6C6.html
#
# sleep for a while ....
# exec time now: 6.425032
# look indside web
# 1215
# https://www.ptt.cc/bbs/Beauty/M.1513299168.A.45B.html
#
# sleep for a while ....
# exec time now: 6.447171
# look indside web
# 1215
# https://www.ptt.cc/bbs/Beauty/M.1513298679.A.7B9.html
#
# sleep for a while ....
# exec time now: 6.463629
# look indside web
# 1214
# https://www.ptt.cc/bbs/Beauty/M.1513263825.A.7BB.html
#
# sleep for a while ....
# exec time now: 6.481004
# look indside web
# 1214
# https://www.ptt.cc/bbs/Beauty/M.1513261968.A.0A1.html
#
# sleep for a while ....
# exec time now: 6.498895
# look indside web
# 1214
# https://www.ptt.cc/bbs/Beauty/M.1513255883.A.B1A.html
#
# sleep for a while ....
# exec time now: 6.517452
# look indside web
# 1214
# https://www.ptt.cc/bbs/Beauty/M.1513253550.A.21C.html
#
# exec time now: 6.535343
# look indside web
# 1214
# https://www.ptt.cc/bbs/Beauty/M.1513251655.A.F79.html
#
# sleep for a while ....
# exec time now: 6.552401
# look indside web
# 1214
# https://www.ptt.cc/bbs/Beauty/M.1513248317.A.57B.html
#
# exec time now: 6.570676
# look indside web
# 1214
# https://www.ptt.cc/bbs/Beauty/M.1513247224.A.817.html
#
# sleep for a while ....
# exec time now: 6.587917
# look indside web
# 1214
# https://www.ptt.cc/bbs/Beauty/M.1513247095.A.EB9.html
#
# sleep for a while ....
# exec time now: 6.604725
# look indside web
# 1214
# https://www.ptt.cc/bbs/Beauty/M.1513241069.A.659.html
#
# sleep for a while ....
# exec time now: 6.621550
# look indside web
# 1214
# https://www.ptt.cc/bbs/Beauty/M.1513240433.A.0DE.html
#
# sleep for a while ....
# exec time now: 6.638292
# look indside web
# 1214
# https://www.ptt.cc/bbs/Beauty/M.1513238544.A.3C6.html
# sleep for a while ....
# exec time now: 6.660847
# look indside web
# 1214
# https://www.ptt.cc/bbs/Beauty/M.1513234691.A.8FB.html
#
# sleep for a while ....
# exec time now: 6.677955
# look indside web
# 1214
# https://www.ptt.cc/bbs/Beauty/M.1513226883.A.ABB.html
#
# sleep for a while ....
# exec time now: 6.697296
# look indside web
# 1214
# https://www.ptt.cc/bbs/Beauty/M.1513224841.A.448.html
#
# sleep for a while ....
# exec time now: 6.715120
# look indside web
# 1214
# https://www.ptt.cc/bbs/Beauty/M.1513224638.A.5C2.html
#
# sleep for a while ....
# exec time now: 6.734810
# look indside web
# 1214
# https://www.ptt.cc/bbs/Beauty/M.1513223596.A.A80.html
#
# sleep for a while ....
# exec time now: 6.752251
# look indside web
# 1214
# https://www.ptt.cc/bbs/Beauty/M.1513222997.A.F0B.html
#
# sleep for a while ....
# exec time now: 6.769076
# look indside web
# 1214
# https://www.ptt.cc/bbs/Beauty/M.1513221183.A.A5D.html
#
# sleep for a while ....
# exec time now: 6.786151
# look indside web
# 1214
# https://www.ptt.cc/bbs/Beauty/M.1513212346.A.5CC.html
#
# sleep for a while ....
# exec time now: 6.803059
# look indside web
# 1214
# https://www.ptt.cc/bbs/Beauty/M.1513211160.A.46E.html
#
# sleep for a while ....
# exec time now: 6.820667
# look indside web
# 1214
# https://www.ptt.cc/bbs/Beauty/M.1513210248.A.D37.html
#
# sleep for a while ....
# exec time now: 6.837742
# look indside web
# 1214
# https://www.ptt.cc/bbs/Beauty/M.1513185981.A.437.html
#
# sleep for a while ....
# exec time now: 6.855533
# look indside web
# 1213
# https://www.ptt.cc/bbs/Beauty/M.1513171107.A.76D.html
#
# sleep for a while ....
# exec time now: 6.873108
# look indside web
# 1213
# https://www.ptt.cc/bbs/Beauty/M.1513169077.A.73F.html
#
# sleep for a while ....
# exec time now: 6.889833
# look indside web
# 1213
# https://www.ptt.cc/bbs/Beauty/M.1513168921.A.CB3.html
#
# sleep for a while ....
# exec time now: 6.906708
# look indside web
# 1213
# https://www.ptt.cc/bbs/Beauty/M.1513168048.A.F4D.html
#
# sleep for a while ....
# exec time now: 6.923649
# look indside web
# 1213
# https://www.ptt.cc/bbs/Beauty/M.1513167206.A.FEF.html
#
# sleep for a while ....
# exec time now: 6.940741
# look indside web
# 1213
# https://www.ptt.cc/bbs/Beauty/M.1513152991.A.254.html
#
# sleep for a while ....
# exec time now: 6.958665
# look indside web
# 1213
# https://www.ptt.cc/bbs/Beauty/M.1513148620.A.8A2.html
#
# sleep for a while ....
# exec time now: 6.975973
# look indside web
# 1213
# https://www.ptt.cc/bbs/Beauty/M.1513146484.A.CEA.html
#
# sleep for a while ....
# exec time now: 6.992731
# look indside web
# 1213
# https://www.ptt.cc/bbs/Beauty/M.1513141794.A.0AC.html
#
# sleep for a while ....
# exec time now: 7.009256
# look indside web
# 1213
# https://www.ptt.cc/bbs/Beauty/M.1513138111.A.EBF.html
#
# sleep for a while ....
# exec time now: 7.026331
# look indside web
# 1213
# https://www.ptt.cc/bbs/Beauty/M.1513136343.A.EC3.html
#
# sleep for a while ....
# exec time now: 7.043372
# look indside web
# 1213
# https://www.ptt.cc/bbs/Beauty/M.1513129782.A.DD8.html
#
# sleep for a while ....
# exec time now: 7.061897
# look indside web
# 1213
# https://www.ptt.cc/bbs/Beauty/M.1513126416.A.66B.html
#
# sleep for a while ....
# exec time now: 7.079255
# look indside web
# 1213
# https://www.ptt.cc/bbs/Beauty/M.1513126390.A.FA5.html
#
# sleep for a while ....
# exec time now: 7.095980
# look indside web
# 1213
# https://www.ptt.cc/bbs/Beauty/M.1513103318.A.A2E.html
#
# sleep for a while ....
# exec time now: 7.115220
# look indside web
# 1213
# https://www.ptt.cc/bbs/Beauty/M.1513097642.A.A09.html
#
# sleep for a while ....
# exec time now: 7.132445
# look indside web
# 1213
# https://www.ptt.cc/bbs/Beauty/M.1513096077.A.3CA.html
#
# sleep for a while ....
# exec time now: 7.149170
# look indside web
# 1213
# https://www.ptt.cc/bbs/Beauty/M.1513095976.A.E38.html
#
# sleep for a while ....
# exec time now: 7.166561
# look indside web
# 1212
# https://www.ptt.cc/bbs/Beauty/M.1513093658.A.143.html
#
# sleep for a while ....
# exec time now: 7.183969
# look indside web
# 1212
# https://www.ptt.cc/bbs/Beauty/M.1513091394.A.85D.html
#
# sleep for a while ....
# exec time now: 7.201227
# look indside web
# 1212
# https://www.ptt.cc/bbs/Beauty/M.1513089990.A.851.html
#
# sleep for a while ....
# exec time now: 7.217985
# look indside web
# 1212
# https://www.ptt.cc/bbs/Beauty/M.1513083123.A.895.html
#
# sleep for a while ....
# exec time now: 7.235093
# look indside web
# 1212
# https://www.ptt.cc/bbs/Beauty/M.1513076621.A.370.html
#
# sleep for a while ....
# exec time now: 7.251935
# look indside web
# 1212
# https://www.ptt.cc/bbs/Beauty/M.1513076345.A.4E2.html
#
# sleep for a while ....
# exec time now: 7.268743
# look indside web
# 1212
# https://www.ptt.cc/bbs/Beauty/M.1513075791.A.2D5.html
#
# sleep for a while ....
# exec time now: 7.285801
# look indside web
# 1212
# https://www.ptt.cc/bbs/Beauty/M.1513067823.A.F5D.html
#
# sleep for a while ....
# exec time now: 7.302693
# look indside web
# 1212
# https://www.ptt.cc/bbs/Beauty/M.1513067744.A.78A.html
#
# sleep for a while ....
# exec time now: 7.321483
# look indside web
# 1212
# https://www.ptt.cc/bbs/Beauty/M.1513065700.A.076.html
#
# sleep for a while ....
# exec time now: 7.339558
# look indside web
# 1212
# https://www.ptt.cc/bbs/Beauty/M.1513064409.A.A17.html
#
# sleep for a while ....
# exec time now: 7.356816
# look indside web
# 1212
# https://www.ptt.cc/bbs/Beauty/M.1513062124.A.D35.html
#
# sleep for a while ....
# exec time now: 7.374157
# look indside web
# 1212
# https://www.ptt.cc/bbs/Beauty/M.1513057856.A.9D7.html
#
# sleep for a while ....
# exec time now: 7.391898
# look indside web
# 1212
# https://www.ptt.cc/bbs/Beauty/M.1513047333.A.74C.html
#
# sleep for a while ....
# exec time now: 7.408723
# look indside web
# 1212
# https://www.ptt.cc/bbs/Beauty/M.1513046367.A.E12.html
#
# sleep for a while ....
# exec time now: 7.425348
# look indside web
# 1212
# https://www.ptt.cc/bbs/Beauty/M.1513043636.A.FDE.html
#
# sleep for a while ....
# exec time now: 7.442523
# look indside web
# 1212
# https://www.ptt.cc/bbs/Beauty/M.1513023105.A.E8A.html
#
# sleep for a while ....
# exec time now: 7.459964
# look indside web
# 1212
# https://www.ptt.cc/bbs/Beauty/M.1513012997.A.0BC.html
#
# sleep for a while ....
# exec time now: 7.477289
# look indside web
# 1212
# https://www.ptt.cc/bbs/Beauty/M.1513011943.A.EFE.html
#
# sleep for a while ....
# exec time now: 7.495047
# look indside web
# 1211
# https://www.ptt.cc/bbs/Beauty/M.1513001332.A.599.html
#
# sleep for a while ....
# exec time now: 7.512471
# look indside web
# 1211
# https://www.ptt.cc/bbs/Beauty/M.1512995500.A.3F9.html
#
# sleep for a while ....
# exec time now: 7.529613
# look indside web
# 1211
# https://www.ptt.cc/bbs/Beauty/M.1512992884.A.75C.html
#
# sleep for a while ....
# exec time now: 7.548220
# look indside web
# 1211
# https://www.ptt.cc/bbs/Beauty/M.1512989545.A.3FA.html
#
# sleep for a while ....
# exec time now: 7.565578
# look indside web
# 1211
# https://www.ptt.cc/bbs/Beauty/M.1512987160.A.BFA.html
#
# sleep for a while ....
# ...
# look indside web
# 107
# https://www.ptt.cc/bbs/Beauty/M.1483766927.A.F18.html
#
# sleep for a while ....
# exec time now: 125.324068
# look indside web
# 107
# https://www.ptt.cc/bbs/Beauty/M.1483759985.A.C11.html
#
# sleep for a while ....
# exec time now: 125.341920
# look indside web
# 107
# https://www.ptt.cc/bbs/Beauty/M.1483755116.A.C36.html
#
# sleep for a while ....
# exec time now: 125.359055
# look indside web
# 107
# https://www.ptt.cc/bbs/Beauty/M.1483748370.A.DE3.html
#
# sleep for a while ....
# exec time now: 125.377157
# look indside web
# 107
# https://www.ptt.cc/bbs/Beauty/M.1483728113.A.681.html
#
# sleep for a while ....
# exec time now: 125.394709
# look indside web
# 107
# https://www.ptt.cc/bbs/Beauty/M.1483723023.A.2F4.html
#
# sleep for a while ....
# exec time now: 125.412777
# look indside web
# 107
# https://www.ptt.cc/bbs/Beauty/M.1483722799.A.FA9.html
#
# sleep for a while ....
# exec time now: 125.433279
# look indside web
# 107
# https://www.ptt.cc/bbs/Beauty/M.1483722181.A.541.html
#
# sleep for a while ....
# exec time now: 125.451331
# look indside web
# 106
# https://www.ptt.cc/bbs/Beauty/M.1483717603.A.57C.html
#
# sleep for a while ....
# exec time now: 125.475434
# look indside web
# 106
# https://www.ptt.cc/bbs/Beauty/M.1483717069.A.4C7.html
#
# sleep for a while ....
# exec time now: 125.494969
# look indside web
# 106
# https://www.ptt.cc/bbs/Beauty/M.1483715441.A.7FC.html
#
# sleep for a while ....
# exec time now: 125.513637
# look indside web
# 106
# https://www.ptt.cc/bbs/Beauty/M.1483715424.A.36D.html
#
# sleep for a while ....
# exec time now: 125.530706
# look indside web
# 106
# https://www.ptt.cc/bbs/Beauty/M.1483712521.A.AFA.html
#
# sleep for a while ....
# exec time now: 125.548191
# look indside web
# 106
# https://www.ptt.cc/bbs/Beauty/M.1483709342.A.FD5.html
#
# sleep for a while ....
# exec time now: 125.566193
# look indside web
# 106
# https://www.ptt.cc/bbs/Beauty/M.1483707001.A.CDA.html
#
# sleep for a while ....
# exec time now: 125.587028
# look indside web
# 106
# https://www.ptt.cc/bbs/Beauty/M.1483706063.A.689.html
#
# sleep for a while ....
# exec time now: 125.605630
# look indside web
# 106
# https://www.ptt.cc/bbs/Beauty/M.1483705089.A.BBA.html
#
# sleep for a while ....
# exec time now: 125.622815
# look indside web
# 106
# https://www.ptt.cc/bbs/Beauty/M.1483705084.A.6CE.html
#
# sleep for a while ....
# exec time now: 125.639783
# look indside web
# 106
# https://www.ptt.cc/bbs/Beauty/M.1483700259.A.0CA.html
#
# sleep for a while ....
# exec time now: 125.658068
# look indside web
# 106
# https://www.ptt.cc/bbs/Beauty/M.1483700087.A.11E.html
#
# sleep for a while ....
# exec time now: 125.676104
# look indside web
# 106
# https://www.ptt.cc/bbs/Beauty/M.1483686086.A.3A4.html
#
# sleep for a while ....
# exec time now: 125.695089
# look indside web
# 106
# https://www.ptt.cc/bbs/Beauty/M.1483680793.A.D6E.html
#
# sleep for a while ....
# exec time now: 125.712974
# look indside web
# 106
# https://www.ptt.cc/bbs/Beauty/M.1483677450.A.91A.html
#
# sleep for a while ....
# exec time now: 125.731009
# look indside web
# 106
# https://www.ptt.cc/bbs/Beauty/M.1483672362.A.357.html
#
# sleep for a while ....
# exec time now: 125.748144
# look indside web
# 106
# https://www.ptt.cc/bbs/Beauty/M.1483670449.A.EF3.html
#
# sleep for a while ....
# exec time now: 125.766013
# look indside web
# 106
# https://www.ptt.cc/bbs/Beauty/M.1483669641.A.244.html
#
# sleep for a while ....
# exec time now: 125.783364
# look indside web
# 106
# https://www.ptt.cc/bbs/Beauty/M.1483659587.A.2A9.html
#
# sleep for a while ....
# exec time now: 125.800116
# look indside web
# 106
# https://www.ptt.cc/bbs/Beauty/M.1483657464.A.25A.html
#
# sleep for a while ....
# exec time now: 125.818534
# look indside web
# 106
# https://www.ptt.cc/bbs/Beauty/M.1483647049.A.1AB.html
#
# sleep for a while ....
# exec time now: 125.835803
# look indside web
# 106
# https://www.ptt.cc/bbs/Beauty/M.1483639844.A.87D.html
#
# sleep for a while ....
# exec time now: 125.854055
# look indside web
# 106
# https://www.ptt.cc/bbs/Beauty/M.1483637597.A.488.html
#
# sleep for a while ....
# exec time now: 125.871940
# look indside web
# 106
# https://www.ptt.cc/bbs/Beauty/M.1483636266.A.152.html
#
# sleep for a while ....
# exec time now: 125.890442
# look indside web
# 106
# https://www.ptt.cc/bbs/Beauty/M.1483632677.A.79C.html
#
# sleep for a while ....
# exec time now: 125.909810
# look indside web
# 105
# https://www.ptt.cc/bbs/Beauty/M.1483626993.A.E30.html
#
# sleep for a while ....
# exec time now: 125.928879
# look indside web
# 105
# https://www.ptt.cc/bbs/Beauty/M.1483625441.A.FAE.html
#
# sleep for a while ....
# exec time now: 125.946364
# look indside web
# 105
# https://www.ptt.cc/bbs/Beauty/M.1483621992.A.04A.html
#
# sleep for a while ....
# exec time now: 125.968783
# look indside web
# 105
# https://www.ptt.cc/bbs/Beauty/M.1483619049.A.EC5.html
# sleep for a while ....
# exec time now: 125.986551
# look indside web
# 105
# https://www.ptt.cc/bbs/Beauty/M.1483618810.A.2B1.html
#
# sleep for a while ....
# exec time now: 126.005487
# look indside web
# 105
# https://www.ptt.cc/bbs/Beauty/M.1483616900.A.1EA.html
#
# sleep for a while ....
# exec time now: 126.023905
# look indside web
# 105
# https://www.ptt.cc/bbs/Beauty/M.1483615571.A.439.html
#
# sleep for a while ....
# exec time now: 126.041923
# look indside web
# 105
# https://www.ptt.cc/bbs/Beauty/M.1483603516.A.378.html
#
# sleep for a while ....
# exec time now: 126.061359
# look indside web
# 105
# https://www.ptt.cc/bbs/Beauty/M.1483603219.A.9ED.html
#
# sleep for a while ....
# exec time now: 126.078260
# look indside web
# 105
# https://www.ptt.cc/bbs/Beauty/M.1483597853.A.9E3.html
#
# sleep for a while ....
# exec time now: 126.095145
# look indside web
# 105
# https://www.ptt.cc/bbs/Beauty/M.1483589523.A.B01.html
#
# sleep for a while ....
# exec time now: 126.113481
# look indside web
# 105
# https://www.ptt.cc/bbs/Beauty/M.1483589435.A.4DE.html
#
# sleep for a while ....
# exec time now: 126.131416
# look indside web
# 105
# https://www.ptt.cc/bbs/Beauty/M.1483583851.A.A81.html
#
# sleep for a while ....
# exec time now: 126.149784
# look indside web
# 105
# https://www.ptt.cc/bbs/Beauty/M.1483579091.A.9B8.html
#
# sleep for a while ....
# exec time now: 126.168036
# look indside web
# 105
# https://www.ptt.cc/bbs/Beauty/M.1483576767.A.44F.html
#
# sleep for a while ....
# exec time now: 126.185538
# look indside web
# 105
# https://www.ptt.cc/bbs/Beauty/M.1483548252.A.1AF.html
#
# sleep for a while ....
# exec time now: 126.203706
# look indside web
# 105
# https://www.ptt.cc/bbs/Beauty/M.1483545676.A.663.html
#
# sleep for a while ....
# exec time now: 126.221358
# look indside web
# 104
# https://www.ptt.cc/bbs/Beauty/M.1483544546.A.088.html
#
# sleep for a while ....
# exec time now: 126.240210
# look indside web
# 104
# https://www.ptt.cc/bbs/Beauty/M.1483544050.A.1C8.html
#
# sleep for a while ....
# exec time now: 126.260812
# look indside web
# 104
# https://www.ptt.cc/bbs/Beauty/M.1483543926.A.FEB.html
#
# sleep for a while ....
# exec time now: 126.278614
# look indside web
# 104
# https://www.ptt.cc/bbs/Beauty/M.1483543709.A.171.html
#
# sleep for a while ....
# exec time now: 126.296182
# look indside web
# 104
# https://www.ptt.cc/bbs/Beauty/M.1483543031.A.AC5.html
#
# sleep for a while ....
# exec time now: 126.313701
# look indside web
# 104
# https://www.ptt.cc/bbs/Beauty/M.1483542952.A.28F.html
#
# sleep for a while ....
# exec time now: 126.332086
# look indside web
# 104
# https://www.ptt.cc/bbs/Beauty/M.1483540140.A.5A3.html
#
# sleep for a while ....
# exec time now: 126.349354
# look indside web
# 104
# https://www.ptt.cc/bbs/Beauty/M.1483533022.A.C54.html
#
# exec time now: 126.369206
# look indside web
# 104
# https://www.ptt.cc/bbs/Beauty/M.1483530634.A.6BE.html
#
# sleep for a while ....
# exec time now: 126.387558
# look indside web
# 104
# https://www.ptt.cc/bbs/Beauty/M.1483525009.A.AA5.html
#
# sleep for a while ....
# exec time now: 126.405243
# look indside web
# 104
# https://www.ptt.cc/bbs/Beauty/M.1483501921.A.7E9.html
#
# sleep for a while ....
# exec time now: 126.422812
# look indside web
# 104
# https://www.ptt.cc/bbs/Beauty/M.1483498369.A.27C.html
#
# sleep for a while ....
# exec time now: 126.442430
# look indside web
# 104
# https://www.ptt.cc/bbs/Beauty/M.1483487643.A.E1F.html
#
# sleep for a while ....
# exec time now: 126.460649
# look indside web
# 104
# https://www.ptt.cc/bbs/Beauty/M.1483486616.A.545.html
#
# sleep for a while ....
# exec time now: 126.479284
# look indside web
# 104
# https://www.ptt.cc/bbs/Beauty/M.1483462987.A.4CB.html
#
# sleep for a while ....
# exec time now: 126.497702
# look indside web
# 104
# https://www.ptt.cc/bbs/Beauty/M.1483460873.A.518.html
#
# sleep for a while ....
# exec time now: 126.515321
# look indside web
# 103
# https://www.ptt.cc/bbs/Beauty/M.1483457888.A.8C2.html
#
# sleep for a while ....
# exec time now: 126.535773
# look indside web
# 103
# https://www.ptt.cc/bbs/Beauty/M.1483457799.A.2E5.html
#
# sleep for a while ....
# exec time now: 126.553741
# look indside web
# 103
# https://www.ptt.cc/bbs/Beauty/M.1483456484.A.3B4.html
#
# sleep for a while ....
# exec time now: 126.574327
# look indside web
# 103
# https://www.ptt.cc/bbs/Beauty/M.1483452673.A.010.html
#
# sleep for a while ....
# exec time now: 126.593112
# look indside web
# 103
# https://www.ptt.cc/bbs/Beauty/M.1483448742.A.80B.html
#
# sleep for a while ....
# exec time now: 126.623832
# look indside web
# 103
# https://www.ptt.cc/bbs/Beauty/M.1483445758.A.CE6.html
#
# sleep for a while ....
# exec time now: 126.643084
# look indside web
# 103
# https://www.ptt.cc/bbs/Beauty/M.1483445124.A.314.html
#
# sleep for a while ....
# exec time now: 126.662536
# look indside web
# 103
# https://www.ptt.cc/bbs/Beauty/M.1483440723.A.7B1.html
#
# sleep for a while ....
# exec time now: 126.681571
# look indside web
# 103
# https://www.ptt.cc/bbs/Beauty/M.1483439325.A.FCD.html
#
# sleep for a while ....
# exec time now: 126.702256
# look indside web
# 103
# https://www.ptt.cc/bbs/Beauty/M.1483435399.A.C54.html
#
# sleep for a while ....
# exec time now: 126.719875
# look indside web
# 103
# https://www.ptt.cc/bbs/Beauty/M.1483435372.A.B71.html
#
# sleep for a while ....
# exec time now: 126.737726
# look indside web
# 103
# https://www.ptt.cc/bbs/Beauty/M.1483434504.A.00F.html
#
# sleep for a while ....
# exec time now: 126.755845
# look indside web
# 103
# https://www.ptt.cc/bbs/Beauty/M.1483434100.A.C3F.html
#
# sleep for a while ....
# exec time now: 126.777180
# look indside web
# 103
# https://www.ptt.cc/bbs/Beauty/M.1483432524.A.2C4.html
#
# sleep for a while ....
# exec time now: 126.800316
# look indside web
# 103
# https://www.ptt.cc/bbs/Beauty/M.1483429864.A.992.html
#
# sleep for a while ....
# exec time now: 126.822001
# look indside web
# 103
# https://www.ptt.cc/bbs/Beauty/M.1483427585.A.95E.html
#
# sleep for a while ....
# exec time now: 126.848237
# look indside web
# 103
# https://www.ptt.cc/bbs/Beauty/M.1483426481.A.DB7.html
#
# sleep for a while ....
# exec time now: 126.865773
# look indside web
# 103
# https://www.ptt.cc/bbs/Beauty/M.1483426138.A.126.html
#
# sleep for a while ....
# exec time now: 126.884341
# look indside web
# 103
# https://www.ptt.cc/bbs/Beauty/M.1483421960.A.5FC.html
#
# sleep for a while ....
# exec time now: 126.902260
# look indside web
# 103
# https://www.ptt.cc/bbs/Beauty/M.1483420405.A.2CB.html
#
# sleep for a while ....
# exec time now: 126.920828
# look indside web
# 103
# https://www.ptt.cc/bbs/Beauty/M.1483417536.A.5EA.html
#
# sleep for a while ....
# exec time now: 126.939013
# look indside web
# 103
# https://www.ptt.cc/bbs/Beauty/M.1483414489.A.E6A.html
#
# sleep for a while ....
# exec time now: 126.968133
# look indside web
# 103
# https://www.ptt.cc/bbs/Beauty/M.1483411100.A.794.html
#
# sleep for a while ....
# exec time now: 126.991735
# look indside web
# 103
# https://www.ptt.cc/bbs/Beauty/M.1483407451.A.18A.html
#
# sleep for a while ....
# exec time now: 127.018738
# look indside web
# 103
# https://www.ptt.cc/bbs/Beauty/M.1483402052.A.4B4.html
#
# sleep for a while ....
# exec time now: 127.049124
# look indside web
# 103
# https://www.ptt.cc/bbs/Beauty/M.1483401964.A.EF9.html
#
# sleep for a while ....
# exec time now: 127.074310
# look indside web
# 102
# https://www.ptt.cc/bbs/Beauty/M.1483372646.A.6A9.html
#
# sleep for a while ....
# exec time now: 127.092262
# look indside web
# 102
# https://www.ptt.cc/bbs/Beauty/M.1483370162.A.1E4.html
#
# sleep for a while ....
# exec time now: 127.110730
# look indside web
# 102
# https://www.ptt.cc/bbs/Beauty/M.1483366918.A.033.html
#
# sleep for a while ....
# exec time now: 127.129199
# look indside web
# 102
# https://www.ptt.cc/bbs/Beauty/M.1483359973.A.551.html
#
# sleep for a while ....
# exec time now: 127.150684
# look indside web
# 102
# https://www.ptt.cc/bbs/Beauty/M.1483354543.A.026.html
#
# sleep for a while ....
# exec time now: 127.168369
# look indside web
# 102
# https://www.ptt.cc/bbs/Beauty/M.1483350907.A.436.html
#
# sleep for a while ....
# exec time now: 127.185821
# look indside web
# 102
# https://www.ptt.cc/bbs/Beauty/M.1483350030.A.A9A.html
#
# sleep for a while ....
# exec time now: 127.203756
# look indside web
# 102
# https://www.ptt.cc/bbs/Beauty/M.1483346948.A.7CB.html
#
# sleep for a while ....
# exec time now: 127.221141
# look indside web
# 102
# https://www.ptt.cc/bbs/Beauty/M.1483341636.A.65B.html
#
# sleep for a while ....
# exec time now: 127.240543
# look indside web
# 102
# https://www.ptt.cc/bbs/Beauty/M.1483340837.A.D60.html
#
# sleep for a while ....
# exec time now: 127.258412
# look indside web
# 102
# https://www.ptt.cc/bbs/Beauty/M.1483336583.A.35E.html
# sleep for a while ....
# exec time now: 127.284298
# look indside web
# 102
# https://www.ptt.cc/bbs/Beauty/M.1483329602.A.82E.html
#
# sleep for a while ....
# exec time now: 127.302683
# look indside web
# 102
# https://www.ptt.cc/bbs/Beauty/M.1483327638.A.A00.html
#
# sleep for a while ....
# exec time now: 127.320985
# look indside web
# 102
# https://www.ptt.cc/bbs/Beauty/M.1483327009.A.473.html
#
# sleep for a while ....
# exec time now: 127.339403
# look indside web
# 102
# https://www.ptt.cc/bbs/Beauty/M.1483303154.A.BE0.html
#
# sleep for a while ....
# exec time now: 127.363422
# look indside web
# 102
# https://www.ptt.cc/bbs/Beauty/M.1483287313.A.5C5.html
#
# sleep for a while ....
# exec time now: 127.382258
# look indside web
# 101
# https://www.ptt.cc/bbs/Beauty/M.1483283992.A.F31.html
#
# sleep for a while ....
# exec time now: 127.402109
# look indside web
# 101
# https://www.ptt.cc/bbs/Beauty/M.1483283407.A.843.html
#
# sleep for a while ....
# exec time now: 127.426729
# look indside web
# 101
# https://www.ptt.cc/bbs/Beauty/M.1483283306.A.9CF.html
#
# sleep for a while ....
# exec time now: 127.444897
# look indside web
# 101
# https://www.ptt.cc/bbs/Beauty/M.1483280432.A.65C.html
#
# sleep for a while ....
# exec time now: 127.467033
# look indside web
# 101
# https://www.ptt.cc/bbs/Beauty/M.1483279874.A.1A5.html
#
# sleep for a while ....
# exec time now: 127.485685
# look indside web
# 101
# https://www.ptt.cc/bbs/Beauty/M.1483275018.A.26B.html
#
# exec time now: 127.504170
# look indside web
# 101
# https://www.ptt.cc/bbs/Beauty/M.1483273646.A.AE5.html
#
# sleep for a while ....
# exec time now: 127.522071
# look indside web
# 101
# https://www.ptt.cc/bbs/Beauty/M.1483271793.A.A89.html
#
# sleep for a while ....
# exec time now: 127.544924
# look indside web
# 101
# https://www.ptt.cc/bbs/Beauty/M.1483255699.A.F98.html
#
# sleep for a while ....
# exec time now: 127.563492
# look indside web
# 101
# https://www.ptt.cc/bbs/Beauty/M.1483249659.A.63C.html
#
# sleep for a while ....
# exec time now: 127.582278
# look indside web
# 101
# https://www.ptt.cc/bbs/Beauty/M.1483248525.A.E83.html
#
# sleep for a while ....
# exec time now: 127.599546
# look indside web
# 101
# https://www.ptt.cc/bbs/Beauty/M.1483248324.A.93F.html
#
# sleep for a while ....
# exec time now: 127.616798
# look indside web
# 101
# https://www.ptt.cc/bbs/Beauty/M.1483247982.A.CA9.html
#
# sleep for a while ....
# exec time now: 127.634099
# look indside web
# 101
# https://www.ptt.cc/bbs/Beauty/M.1483242231.A.E8F.html
#
# sleep for a while ....
# exec time now: 127.651468
# look indside web
# 101
# https://www.ptt.cc/bbs/Beauty/M.1483242009.A.A59.html
#
# sleep for a while ....
# exec time now: 127.674920
# look indside web
# 101
# https://www.ptt.cc/bbs/Beauty/M.1483240311.A.1B2.html
#
# sleep for a while ....
# exec time now: 127.693022
# look indside web
# 101
# https://www.ptt.cc/bbs/Beauty/M.1483237869.A.6DC.html
#
# sleep for a while ....
# exec time now: 127.711190
# look indside web
# 101
# https://www.ptt.cc/bbs/Beauty/M.1483230294.A.354.html
#
# sleep for a while ....
# exec time now: 127.732876
# look indside web
# 101
# https://www.ptt.cc/bbs/Beauty/M.1483208127.A.95F.html
#
# sleep for a while ....
# exec time now: 127.750994
# look indside web
# 101
# https://www.ptt.cc/bbs/Beauty/M.1483208018.A.411.html
#
# sleep for a while ....
# exec time now: 127.772280
# total time: 127.772680

# %%
string = '202,[正妹] 功夫瑜珈 Disha Patani, Amyra Dastur,https://www.ptt.cc/bbs/Beauty/M.1485966309.A.6E2.html'
line_list=[x for x in string.split(',')]
url = line_list[len(line_list)-1]
date = int(line_list[0])
print(url)
print(date)
# Out:
# https://www.ptt.cc/bbs/Beauty/M.1485966309.A.6E2.html
# 202
